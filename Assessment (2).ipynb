# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yisau Idris Ayobami**
# I am Interested in becoming a Medical Radiographer with sound knowledge in Data Science, AI in Healthcare & Web Development

# %% [markdown]
# *I am interested in becoming a data scientist because i feel it will be a big step towards me achieving my final end goal which is to help the human cause at large*

# %% [markdown]
# ### My code in the cell below is to solve a bit of a mathematical problem

# %%
print(((10-2+5)*12)/3)
# Out:
# 52.0

# %% [markdown]
# [My WhatsApp](https://wa.me/qr/ID27X4ZAIVDGG1)
#
# ***
#
# 1. Idris
#      1. He is a student
#           1. He loves manipulating data
#                1. He likes Coursera
#                     - He's from Nigeria
#
#
# | --- | --- | --- |
#
# | Name | Age | Sex |
#
# | --- | --- | --- |
#
# | Idris | 20 Years | Male |
#
# | --- | --- | --- |
#
#
# ![1200px-Jupyter_logo.svg.webp](attachment:1200px-Jupyter_logo.svg.webp)
